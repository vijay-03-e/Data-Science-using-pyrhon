# %%
import pandas as pd
df=pd.read_csv("D:\\Data science\\assignments\\ToyotaCorolla - MLR.csv")
df
# Out:
#       Price  Age_08_04     KM Fuel_Type   HP  Automatic    cc  Doors  \
# 0     13500         23  46986    Diesel   90          0  2000      3
# 1     13750         23  72937    Diesel   90          0  2000      3
# 2     13950         24  41711    Diesel   90          0  2000      3
# 3     14950         26  48000    Diesel   90          0  2000      3
# 4     13750         30  38500    Diesel   90          0  2000      3
# ...     ...        ...    ...       ...  ...        ...   ...    ...
# 1431   7500         69  20544    Petrol   86          0  1300      3
# 1432  10845         72  19000    Petrol   86          0  1300      3
# 1433   8500         71  17016    Petrol   86          0  1300      3
# 1434   7250         70  16916    Petrol   86          0  1300      3
# 1435   6950         76      1    Petrol  110          0  1600      5
#
#       Cylinders  Gears  Weight
# 0             4      5    1165
# 1             4      5    1165
# 2             4      5    1165
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1436 entries, 0 to 1435
# Data columns (total 11 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Price      1436 non-null   int64
#  1   Age_08_04  1436 non-null   int64
#  2   KM         1436 non-null   int64
#  3   Fuel_Type  1436 non-null   object
#  4   HP         1436 non-null   int64
#  5   Automatic  1436 non-null   int64
#  6   cc         1436 non-null   int64
#  7   Doors      1436 non-null   int64
#  8   Cylinders  1436 non-null   int64
#  9   Gears      1436 non-null   int64
#  10  Weight     1436 non-null   int64
# dtypes: int64(10), object(1)
# memory usage: 123.5+ KB

# %% [markdown]
# # 1. Perform exploratory data analysis (EDA) to gain insights into the dataset.

# %%
# Exploratory Data Analysis (EDA

# 1. Data Cleaning:

# Check for missing values
df.isnull().sum()

# Check for outliers
df.describe()
# Out:
#               Price    Age_08_04             KM           HP    Automatic  \
# count   1436.000000  1436.000000    1436.000000  1436.000000  1436.000000
# mean   10730.824513    55.947075   68533.259749   101.502089     0.055710
# std     3626.964585    18.599988   37506.448872    14.981080     0.229441
# min     4350.000000     1.000000       1.000000    69.000000     0.000000
# 25%     8450.000000    44.000000   43000.000000    90.000000     0.000000
# 50%     9900.000000    61.000000   63389.500000   110.000000     0.000000
# 75%    11950.000000    70.000000   87020.750000   110.000000     0.000000
# max    32500.000000    80.000000  243000.000000   192.000000     1.000000
#
#                 cc        Doors  Cylinders        Gears      Weight
# count   1436.00000  1436.000000     1436.0  1436.000000  1436.00000
# mean    1576.85585     4.033426        4.0     5.026462  1072.45961
# std      424.38677     0.952677        0.0     0.188510    52.64112
# ...

# %%
#Provide visualizations and summary statistics of the variables

# Visualize the distribution of each variable
import matplotlib.pyplot as plt
df.hist()
plt.show()

# %%
# catogorical data to numerical data

from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
df["Fuel_Type"] = le.fit_transform(df["Fuel_Type"])
df["Fuel_Type"]
# Out:
# 0       1
# 1       1
# 2       1
# 3       1
# 4       1
#        ..
# 1431    2
# 1432    2
# 1433    2
# 1434    2
# 1435    2
# Name: Fuel_Type, Length: 1436, dtype: int32

# %%
# Calculate summary statistics
df.describe()
# Out:
#               Price    Age_08_04             KM    Fuel_Type           HP  \
# count   1436.000000  1436.000000    1436.000000  1436.000000  1436.000000
# mean   10730.824513    55.947075   68533.259749     1.868384   101.502089
# std     3626.964585    18.599988   37506.448872     0.371572    14.981080
# min     4350.000000     1.000000       1.000000     0.000000    69.000000
# 25%     8450.000000    44.000000   43000.000000     2.000000    90.000000
# 50%     9900.000000    61.000000   63389.500000     2.000000   110.000000
# 75%    11950.000000    70.000000   87020.750000     2.000000   110.000000
# max    32500.000000    80.000000  243000.000000     2.000000   192.000000
#
#          Automatic           cc        Doors  Cylinders        Gears  \
# count  1436.000000   1436.00000  1436.000000     1436.0  1436.000000
# mean      0.055710   1576.85585     4.033426        4.0     5.026462
# std       0.229441    424.38677     0.952677        0.0     0.188510
# ...

# %%
# finding correlation 
df.corr()
# Out:
#               Price  Age_08_04        KM  Fuel_Type        HP  Automatic  \
# Price      1.000000  -0.876590 -0.569960  -0.022157  0.314990   0.033081
# Age_08_04 -0.876590   1.000000  0.505672   0.080261 -0.156622   0.031717
# KM        -0.569960   0.505672  1.000000  -0.420586 -0.333538  -0.081854
# Fuel_Type -0.022157   0.080261 -0.420586   1.000000  0.409476   0.069718
# HP         0.314990  -0.156622 -0.333538   0.409476  1.000000   0.013144
# Automatic  0.033081   0.031717 -0.081854   0.069718  0.013144   1.000000
# cc         0.126389  -0.098084  0.102683  -0.277239  0.035856   0.066740
# Doors      0.185326  -0.148359 -0.036197  -0.026935  0.092424  -0.027654
# Cylinders       NaN        NaN       NaN        NaN       NaN        NaN
# Gears      0.063104  -0.005364  0.015023   0.069655  0.209477  -0.098555
# Weight     0.581198  -0.470253 -0.028598  -0.505303  0.089614   0.057249
#
#                  cc     Doors  Cylinders     Gears    Weight
# ...

# %%
# Replace missing values with the corresponding column mean
df.fillna(df.mean(), inplace=True)

# %%
# Split data into features (X) and target variable (y)
X = df[['Age_08_04', 'KM', 'Fuel_Type', 'HP', 'Automatic', 'cc', 'Doors', 'Weight', 'Cylinders','Gears']]
Y = df['Price']

# %%
# Standardize numerical features

from sklearn.preprocessing import StandardScaler

SS= StandardScaler()
X_SS=SS.fit_transform(X)

# Convert scaled features back to a DataFrame
X_SS=pd.DataFrame(X_SS)
X_SS.columns=list(X)
# Display the  scaled data
X_SS
# Out:
#       Age_08_04        KM  Fuel_Type        HP  Automatic        cc     Doors  \
# 0     -1.771966 -0.574695  -2.337868 -0.768042  -0.242893  0.997419 -1.085139
# 1     -1.771966  0.117454  -2.337868 -0.768042  -0.242893  0.997419 -1.085139
# 2     -1.718184 -0.715386  -2.337868 -0.768042  -0.242893  0.997419 -1.085139
# 3     -1.610620 -0.547650  -2.337868 -0.768042  -0.242893  0.997419 -1.085139
# 4     -1.395491 -0.801028  -2.337868 -0.768042  -0.242893  0.997419 -1.085139
# ...         ...       ...        ...       ...        ...       ...       ...
# 1431   0.702015 -1.279939   0.354336 -1.035138  -0.242893 -0.652594 -1.085139
# 1432   0.863362 -1.321120   0.354336 -1.035138  -0.242893 -0.652594 -1.085139
# 1433   0.809579 -1.374036   0.354336 -1.035138  -0.242893 -0.652594 -1.085139
# 1434   0.755797 -1.376703   0.354336 -1.035138  -0.242893 -0.652594 -1.085139
# 1435   1.078490 -1.827849   0.354336  0.567440  -0.242893  0.054555  1.014941
#
# ...

# %%
# 2.Split the dataset into training and testing sets (e.g., 80% training, 20% testing).

from sklearn.model_selection import train_test_split

X_train, X_test,Y_train, Y_test = train_test_split(X_SS, Y, test_size=0.2, random_state=42)

# %%
# 3. Build a multiple linear regression model using the training dataset. Interpret the coefficients of the model. Build minimum of 3 different models.

# model 1
X = df[['Age_08_04', 'KM', 'Fuel_Type', 'HP', 'Automatic', 'cc', 'Doors', 'Weight', 'Cylinders','Gears']]
Y = df['Price']

# model 2
X1 = df[['Age_08_04', 'KM', 'Automatic', 'cc', 'Doors', 'Weight', 'Cylinders','Gears']]
Y1 = df['Price']

# model 3
X2 = df[['Age_08_04', 'KM', 'Fuel_Type', 'HP', 'Automatic', 'Weight', 'Cylinders','Gears']]
Y2 = df['Price']

# %%
# 4.Evaluate the performance of the model using appropriate evaluation metrics on the testing dataset.
from sklearn.linear_model import LinearRegression
import numpy as np
MLR = LinearRegression()

# fit the model
MLR.fit(X_train, Y_train)
# predictions
y_pred = MLR.predict(X_test)
 # evalute the model
from sklearn.metrics import mean_squared_error, r2_score
mse = mean_squared_error(Y_test,y_pred)
r2=r2_score(Y_test,y_pred)
print("Model 1 :")
print("Mean squared error:", mse)
print("Root Mean squared error:", np.sqrt(mse))
print("R square:", r2)
print("VIF:", 1 / (1-r2))
# Out:
# Model 1 :
# Mean squared error: 2096851.1400177036
# Root Mean squared error: 1448.050807125808
# R square: 0.8428476112018002
# VIF: 6.3632503943933365

# %%
# model 2
X1 = df[['Age_08_04', 'KM', 'Automatic', 'cc', 'Doors', 'Weight', 'Cylinders','Gears']]
Y1 = df['Price']

from sklearn.model_selection import train_test_split

X1_train, X1_test,Y1_train, Y1_test = train_test_split(X1, Y1, test_size=0.2, random_state=42)


MLR1 = LinearRegression()

# fit the model
MLR1.fit(X1_train, Y1_train)
# predictions
y1_pred = MLR1.predict(X1_test)

# evalute the model

from sklearn.metrics import mean_squared_error, r2_score
mse1 = mean_squared_error(Y1_test,y1_pred)
r2_1=r2_score(Y1_test,y1_pred)
print("Model 2 :")
print("Mean squared error:", mse1)
print("Root Mean squared error:", np.sqrt(mse1))
print("R square:", r2_1)
print("VIF:", 1 / (1-r2_1))
# Out:
# Model 2 :
# Mean squared error: 2166752.42292782
# Root Mean squared error: 1471.989274053252
# R square: 0.8376087302055599
# VIF: 6.157966504392946

# %%
# model 3
X2 = df[['Age_08_04', 'KM', 'Fuel_Type', 'HP', 'Automatic', 'Weight', 'Cylinders','Gears']]
Y2 = df['Price']

from sklearn.model_selection import train_test_split

X2_train, X2_test,Y2_train, Y2_test = train_test_split(X2, Y2, test_size=0.2, random_state=42)


MLR2 = LinearRegression()

# fit the model
MLR2.fit(X2_train, Y2_train)
# predictions
y2_pred = MLR2.predict(X2_test)

# evalute the model

from sklearn.metrics import mean_squared_error, r2_score
mse2 = mean_squared_error(Y2_test,y2_pred)
r2_2=r2_score(Y2_test,y2_pred)
print("Model 3 :")
print("Mean squared error:", mse2)
print("Root Mean squared error:", np.sqrt(mse2))
print("R square:", r2_2)
print("VIF:", 1 / (1-r2_2))
# Out:
# Model 3 :
# Mean squared error: 2092425.7029662703
# Root Mean squared error: 1446.5219331093015
# R square: 0.8431792837706517
# VIF: 6.3767085372669285

# %%
# 5.Apply Lasso and Ridge methods on the model.

# Apply Ridge method on the model

from sklearn.linear_model import LinearRegression
LR= LinearRegression()


# fit the model
LR.fit(X_train,Y_train)

# predictions
y_pred_train = LR.predict(X_train)
y_pred_test =LR.predict(X_test)


df_coef = pd.concat([pd.DataFrame(list(X_SS)),pd.DataFrame(LR.coef_)], axis=1)
df_coef

# import the model
from sklearn.linear_model import Ridge
Ridge = Ridge(alpha=300)
Ridge.fit(X_train,Y_train)

#evalute the model

from sklearn.metrics import mean_squared_error, r2_score
mse_Ridge = mean_squared_error(Y_test,y_pred)
r2_Ridge=r2_score(Y_test,y_pred)
print("Ridge method :")
print("Mean squared error:", mse_Ridge)
print("Root Mean squared error:", np.sqrt(mse_Ridge))
print("R square:", r2_Ridge)
print("VIF:", 1 / (1-r2_Ridge))

Ridge.coef_

df_coef["Ridge_coef"] =Ridge.coef_
df_coef
# Out:
# Ridge method :
# Mean squared error: 2096851.1400177036
# Root Mean squared error: 1448.050807125808
# R square: 0.8428476112018002
# VIF: 6.3632503943933365
#            0            0   Ridge_coef
# 0  Age_08_04 -2257.926049 -1795.525269
# 1         KM  -634.972882  -764.998756
# 2  Fuel_Type   320.204724   103.550467
# 3         HP   309.375607   341.422374
# 4  Automatic    56.238711    45.103400
# 5         cc   -31.188093    24.564482
# 6      Doors   -34.550735    60.438178
# 7     Weight  1237.195566  1007.918515
# 8  Cylinders     0.000000     0.000000
# 9      Gears    99.928890   101.367930

# %%
# Apply Lasso method on the model
    
from sklearn.linear_model import Lasso

# Create a Lasso regression model
lasso = Lasso()

# Fit the model
lasso.fit(X_train, Y_train)
X_train,X_test,Y_train,Y_test  = train_test_split(X_SS,Y,test_size = 0.2,random_state=499)
# Predict on the test set
y_pred_lasso = lasso.predict(X_test)

df_coef = pd.concat([pd.DataFrame(list(X_SS)),pd.DataFrame(LR.coef_)], axis=1)
df_coef

# evalute the model

from sklearn.metrics import mean_squared_error, r2_score
mse_lasso = mean_squared_error(Y_test,y_pred)
r2_lasso=r2_score(Y_test,y_pred)
print("lasso method :")
print("Mean squared error:", mse_lasso)
print("Root Mean squared error:", np.sqrt(mse_lasso))
print("R square:", r2_lasso)
print("VIF:", 1 / (1-r2_lasso))



lasso.coef_

df_coef["lasso_coef" ] =lasso.coef_

df_coef
# Out:
# lasso method :
# Mean squared error: 28177685.979618467
# Root Mean squared error: 5308.265816593821
# R square: -0.9324735000824771
# VIF: 0.517471520285955
#            0            0   lasso_coef
# 0  Age_08_04 -2257.926049 -2257.579519
# 1         KM  -634.972882  -635.196227
# 2  Fuel_Type   320.204724   318.338971
# 3         HP   309.375607   309.265706
# 4  Automatic    56.238711    55.390263
# 5         cc   -31.188093   -29.975454
# 6      Doors   -34.550735   -33.006404
# 7     Weight  1237.195566  1234.392032
# 8  Cylinders     0.000000     0.000000
# 9      Gears    99.928890    99.356676

# %%
df_coef = pd.concat([pd.DataFrame(list(X_SS)),pd.DataFrame(LR.coef_)], axis=1)
df_coef["Ridge_coef"] =Ridge.coef_
df_coef["lasso_coef" ] =lasso.coef_
df_coef
# Out:
#            0            0   Ridge_coef   lasso_coef
# 0  Age_08_04 -2257.926049 -1795.525269 -2257.579519
# 1         KM  -634.972882  -764.998756  -635.196227
# 2  Fuel_Type   320.204724   103.550467   318.338971
# 3         HP   309.375607   341.422374   309.265706
# 4  Automatic    56.238711    45.103400    55.390263
# 5         cc   -31.188093    24.564482   -29.975454
# 6      Doors   -34.550735    60.438178   -33.006404
# 7     Weight  1237.195566  1007.918515  1234.392032
# 8  Cylinders     0.000000     0.000000     0.000000
# 9      Gears    99.928890   101.367930    99.356676

# %%
# dropping the coloumns which has 0
X_new = X_SS.drop(X_SS.columns[[8]],axis=1)
X_new
# Out:
#       Age_08_04        KM  Fuel_Type        HP  Automatic        cc     Doors  \
# 0     -1.771966 -0.574695  -2.337868 -0.768042  -0.242893  0.997419 -1.085139
# 1     -1.771966  0.117454  -2.337868 -0.768042  -0.242893  0.997419 -1.085139
# 2     -1.718184 -0.715386  -2.337868 -0.768042  -0.242893  0.997419 -1.085139
# 3     -1.610620 -0.547650  -2.337868 -0.768042  -0.242893  0.997419 -1.085139
# 4     -1.395491 -0.801028  -2.337868 -0.768042  -0.242893  0.997419 -1.085139
# ...         ...       ...        ...       ...        ...       ...       ...
# 1431   0.702015 -1.279939   0.354336 -1.035138  -0.242893 -0.652594 -1.085139
# 1432   0.863362 -1.321120   0.354336 -1.035138  -0.242893 -0.652594 -1.085139
# 1433   0.809579 -1.374036   0.354336 -1.035138  -0.242893 -0.652594 -1.085139
# 1434   0.755797 -1.376703   0.354336 -1.035138  -0.242893 -0.652594 -1.085139
# 1435   1.078490 -1.827849   0.354336  0.567440  -0.242893  0.054555  1.014941
#
#         Weight     Gears
# ...

# %%
### Cross validation method
training_loss = []
test_loss = []

for i in range(0,500,1):
    X_train,X_test,Y_train,Y_test  = train_test_split(X_new,Y,test_size = 0.3,random_state=i)
    LR.fit(X_train,Y_train)
    y_pred_train = LR.predict(X_train)
    y_pred_test = LR.predict(X_test)
    training_loss.append(np.sqrt(mean_squared_error(Y_train,y_pred_train)))
    test_loss.append(np.sqrt(mean_squared_error(Y_test,y_pred_test)))

import numpy as np
print("CV- Training  loss: ",np.mean(training_loss).round(2))
print("CV- Test loss: ",np.mean(test_loss).round(2))
# Out:
# CV- Training  loss:  1320.33
# CV- Test loss:  1494.39

# %% [markdown]
# ###  Interview Questions
#
#
# ##1.What is Normalization & Standardization and how is it helpful?
#
# Normalization & Standardization are two common techniques used in data preprocessing to transform data into a more suitable format for machine learning algorithms.
#
# Normalization scales the values of each feature to a range between 0 and 1. This is useful when the features have different units or scales, as it ensures that no single feature dominates the model.
#
# Standardization scales the values of each feature to have a mean of 0 and a standard deviation of 1. This is useful when the features are normally distributed, as it helps to improve the performance of many machine learning algorithms.
#
# Both normalization and standardization can be helpful in improving the performance of machine learning models by:
#
# * Reducing the influence of outliers
# * Making the data more comparable
# * Improving the convergence of gradient-based algorithms
#
# ###############################################################################################################################
#
#
# ##2.What techniques can be used to address multicollinearity in multiple linear regression?
#
# 1.Feature selection:
#   - Identify and remove features that are highly correlated with each other.
#   - This can be done using correlation analysis or by using a technique such as principal component analysis (PCA).
#
# 2.Ridge regression:
#   - This is a type of linear regression that adds a penalty term to the cost function to discourage large coefficients.
#   - This can help to reduce the impact of multicollinearity on the model.
#
# 3.Lasso regression:
#   - This is another type of linear regression that adds a penalty term to the cost function to encourage the coefficients to be sparse.
#   - This can help to reduce the impact of multicollinearity on the model and can also lead to feature selection.
