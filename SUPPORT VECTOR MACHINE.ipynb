# %% [markdown]
# # Task 1: Exploratory Data Analysis (EDA)

# %%
# 1.Load the Mushroom dataset and perform fundamental data exploration.

# Load data
import pandas as pd
df=pd.read_csv("D:\\Data science\\assignments\\mushroom.csv")
df
# Out:
#       Unnamed: 0 cap_shape cap_surface cap_color bruises     odor  \
# 0           1167    sunken       scaly     white      no    anise
# 1           1037    sunken     fibrous       red      no    anise
# 2            309      flat     grooves    purple     yes     foul
# 3            282      bell       scaly      pink     yes    fishy
# 4            820      flat      smooth    yellow     yes    musty
# ...          ...       ...         ...       ...     ...      ...
# 1995         863    sunken       scaly     brown     yes     foul
# 1996        1160    sunken       scaly    purple     yes    musty
# 1997         265    convex     grooves     green     yes    fishy
# 1998         411      bell      smooth     white      no  pungent
# 1999        1073    convex       scaly    yellow     yes  pungent
#
#      gill_attachment gill_spacing gill_size gill_color  ...  veil_type  \
# 0         descending      distant     broad       pink  ...    partial
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2000 entries, 0 to 1999
# Data columns (total 26 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Unnamed: 0                2000 non-null   int64
#  1   cap_shape                 2000 non-null   object
#  2   cap_surface               2000 non-null   object
#  3   cap_color                 2000 non-null   object
#  4   bruises                   2000 non-null   object
#  5   odor                      2000 non-null   object
#  6   gill_attachment           2000 non-null   object
#  7   gill_spacing              2000 non-null   object
#  8   gill_size                 2000 non-null   object
#  9   gill_color                2000 non-null   object
#  10  stalk_shape               2000 non-null   object
#  11  stalk_root                2000 non-null   object
#  12  stalk_surface_above_ring  2000 non-null   object
# ...

# %%
# missing values
df.isnull().sum()
# Out:
# Unnamed: 0                  0
# cap_shape                   0
# cap_surface                 0
# cap_color                   0
# bruises                     0
# odor                        0
# gill_attachment             0
# gill_spacing                0
# gill_size                   0
# gill_color                  0
# stalk_shape                 0
# stalk_root                  0
# stalk_surface_above_ring    0
# stalk_surface_below_ring    0
# stalk_color_above_ring      0
# stalk_color_below_ring      0
# veil_type                   0
# veil_color                  0
# ring_number                 0
# ring_type                   0
# spore_print_color           0
# population                  0
# habitat                     0
# class                       0
# stalk_height                0
# cap_diameter                0
# dtype: int64

# %%
df.describe()
# Out:
#         Unnamed: 0  stalk_height  cap_diameter
# count  2000.000000   2000.000000   2000.000000
# mean    624.974000      8.449118     12.314345
# std     375.091938      3.697217      7.048845
# min       0.000000      2.000000      1.000000
# 25%     290.000000      5.291009      5.723521
# 50%     607.000000      8.318596     12.124902
# 75%     957.250000     11.781272     18.698605
# max    1279.000000     15.095066     25.000054

# %%
# 2.Utilize histograms, box plots, or density plots to understand feature distributions.

import matplotlib.pyplot as plt
import seaborn as sns

# Histogram for df

df.hist(figsize=(10, 8), bins=10)
plt.show()

# %%
# Boxplot 
sns.boxplot(data=df, orient="v")
plt.show()

# %%
# scatter plot
for col in df.columns:
  plt.scatter(df.index, df[col])
  plt.title(col)
  plt.show()

# %%
# Pair plot to visualize relationships between features
sns.pairplot(df)
plt.show()

# %%
# 3.Investigate feature correlations to discern relationships within the data.

# data transformation
from sklearn.preprocessing import LabelEncoder
LE=LabelEncoder()
for column in df.columns:
    df[column] = LE.fit_transform(df[column])

# correlation matrix

df.corr()
# Out:
#                           Unnamed: 0  cap_shape  cap_surface  cap_color  \
# Unnamed: 0                  1.000000   0.075763    -0.018949   0.023832
# cap_shape                   0.075763   1.000000    -0.003244   0.009615
# cap_surface                -0.018949  -0.003244     1.000000   0.003153
# cap_color                   0.023832   0.009615     0.003153   1.000000
# bruises                    -0.046098  -0.001190    -0.021352   0.016445
# odor                       -0.012166  -0.030119    -0.021926  -0.065410
# gill_attachment            -0.005352   0.015477    -0.010513   0.023835
# gill_spacing                0.047559  -0.048783     0.068918  -0.015628
# gill_size                  -0.022678   0.040497    -0.038490   0.009888
# gill_color                  0.038787   0.032123     0.045561  -0.005898
# stalk_shape                -0.022794   0.011573    -0.024032  -0.020397
# stalk_root                  0.012135   0.057405    -0.008284  -0.004423
# ...

# %% [markdown]
# # Task 2: Data Preprocessing

# %%
# 1.Encode categorical variables if necessary.
 # done in task 1 step 3

# %%
# 2.Split the dataset into training and testing sets.

X = df.drop(['class'], axis=1)  
Y = df["class"]  

from sklearn.model_selection import train_test_split

X_train,X_test,Y_train,Y_test  = train_test_split(X,Y,test_size = 0.2)

# %% [markdown]
# # Task 3: Data Visualization

# %%
# 1.Employ scatter plots, pair plots, or relevant visualizations to comprehend feature distributions and relationships.
# 2.Visualize class distributions to gauge dataset balance or imbalance.

# shown above all Visualization in task 1

# %% [markdown]
# # Task 4: SVM Implementation

# %%
# 1.Implement a basic SVM classifier using Python libraries like scikit-learn.
# 2.Train the SVM model on the training data.
from sklearn.model_selection import train_test_split
import numpy as np
# import the model
from sklearn.svm import SVC
# rbf
# clf = SVC(C=1.0,kernel='linear')
#clf = SVC(C=1.0,kernel='poly',degree=2)
#clf = SVC(C=1.0,kernel='poly',degree=3)
clf = SVC(C=1.0,kernel='rbf',gamma='scale')

###  --> Cross validation method
training_acc = []
test_acc = []
traning_loss = []
test_loss = []

from sklearn.metrics import accuracy_score,log_loss

X_train,X_test,Y_train,Y_test  = train_test_split(X,Y,test_size = 0.3,random_state=42)
clf.fit(X_train,Y_train)
y_pred_train = clf.predict(X_train)
y_pred_test = clf.predict(X_test)
training_acc.append(accuracy_score(Y_train,y_pred_train))
test_acc.append(accuracy_score(Y_test,y_pred_test))
traning_loss.append(log_loss(Y_train,y_pred_train))
test_loss.append(log_loss(Y_test,y_pred_test))

import numpy as np
print("CV- Traning Accuracy: ",np.mean(training_acc).round(2))
print("CV- Test Accuracy: ",np.mean(test_acc).round(2))
print("CV- Traning loss: ",np.mean(traning_loss).round(2))
print("CV- Test loss: ",np.mean(test_loss).round(2))
# Out:
# CV- Traning Accuracy:  0.7
# CV- Test Accuracy:  0.69
# CV- Traning loss:  10.68
# CV- Test loss:  11.11

# %%
# 3.Evaluate model performance on the testing data using appropriate metrics (e.g., accuracy, precision, recall, F1-score).
# Evaluate the performance on test data using metrics like accuracy, precision, recall, and F1-score.

from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score

accuracy_rbf = accuracy_score(Y_test,y_pred_test)
precision_rbf = precision_score(Y_test, y_pred_test, average='weighted')
recall_rbf = recall_score(Y_test, y_pred_test, average='weighted')
f1_rbf = f1_score(Y_test, y_pred_test, average='weighted')

# printing scores

print("Accuracy:", accuracy_rbf)
print("Precision:", precision_rbf)
print("Recall:", recall_rbf)
print("F1 Score:", f1_rbf)
# Out:
# Accuracy: 0.6916666666666667
# Precision: 0.4784027777777778
# Recall: 0.6916666666666667
# F1 Score: 0.56559934318555
# C:\Users\gmani\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
# Linear
clf = SVC(C=1.0,kernel='linear')

###  --> Cross validation method
training_acc = []
test_acc = []
traning_loss = []
test_loss = []

from sklearn.metrics import accuracy_score,log_loss

X_train,X_test,Y_train,Y_test  = train_test_split(X,Y,test_size = 0.3,random_state=42)
clf.fit(X_train,Y_train)
y_pred_train = clf.predict(X_train)
y_pred_test = clf.predict(X_test)
training_acc.append(accuracy_score(Y_train,y_pred_train))
test_acc.append(accuracy_score(Y_test,y_pred_test))
traning_loss.append(log_loss(Y_train,y_pred_train))
test_loss.append(log_loss(Y_test,y_pred_test))

import numpy as np
print("CV- Traning Accuracy: ",np.mean(training_acc).round(2))
print("CV- Test Accuracy: ",np.mean(test_acc).round(2))
print("CV- Traning loss: ",np.mean(traning_loss).round(2))
print("CV- Test loss: ",np.mean(test_loss).round(2))
print("#===============================================================")
# Evaluate the performance on test data using metrics like accuracy, precision, recall, and F1-score.

from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score

accuracy_Linear = accuracy_score(Y_test,y_pred_test)
precision_Linear = precision_score(Y_test, y_pred_test, average='weighted')
recall_Linear = recall_score(Y_test, y_pred_test, average='weighted')
f1_Linear = f1_score(Y_test, y_pred_test, average='weighted')

# printing scores

print("Accuracy:", accuracy_Linear)
print("Precision:", precision_Linear)
print("Recall:", recall_Linear)
print("F1 Score:", f1_Linear)
# Out:
# CV- Traning Accuracy:  0.7
# CV- Test Accuracy:  0.69
# CV- Traning loss:  10.68
# CV- Test loss:  11.11
# #===============================================================
# Accuracy: 0.6916666666666667
# Precision: 0.4784027777777778
# Recall: 0.6916666666666667
# F1 Score: 0.56559934318555
# C:\Users\gmani\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
# poly2
clf = SVC(C=1.0,kernel='poly',degree=2)

###  --> Cross validation method
training_acc = []
test_acc = []
traning_loss = []
test_loss = []

from sklearn.metrics import accuracy_score,log_loss

X_train,X_test,Y_train,Y_test  = train_test_split(X,Y,test_size = 0.3,random_state=42)
clf.fit(X_train,Y_train)
y_pred_train = clf.predict(X_train)
y_pred_test = clf.predict(X_test)
training_acc.append(accuracy_score(Y_train,y_pred_train))
test_acc.append(accuracy_score(Y_test,y_pred_test))
traning_loss.append(log_loss(Y_train,y_pred_train))
test_loss.append(log_loss(Y_test,y_pred_test))

import numpy as np
print("CV- Traning Accuracy: ",np.mean(training_acc).round(2))
print("CV- Test Accuracy: ",np.mean(test_acc).round(2))
print("CV- Traning loss: ",np.mean(traning_loss).round(2))
print("CV- Test loss: ",np.mean(test_loss).round(2))
print("#===============================================================")
# Evaluate the performance on test data using metrics like accuracy, precision, recall, and F1-score.

from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score

accuracy_poly2 = accuracy_score(Y_test,y_pred_test)
precision_poly2 = precision_score(Y_test, y_pred_test, average='weighted')
recall_poly2 = recall_score(Y_test, y_pred_test, average='weighted')
f1_poly2 = f1_score(Y_test, y_pred_test, average='weighted')

# printing scores

print("Accuracy:", accuracy_poly2)
print("Precision:", precision_poly2)
print("Recall:", recall_poly2)
print("F1 Score:", f1_poly2)
# Out:
# CV- Traning Accuracy:  0.7
# CV- Test Accuracy:  0.69
# CV- Traning loss:  10.68
# CV- Test loss:  11.11
# #===============================================================
# Accuracy: 0.6916666666666667
# Precision: 0.4784027777777778
# Recall: 0.6916666666666667
# F1 Score: 0.56559934318555
# C:\Users\gmani\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
#poly3
clf = SVC(C=1.0,kernel='poly',degree=3)
###  --> Cross validation method
training_acc = []
test_acc = []
traning_loss = []
test_loss = []

from sklearn.metrics import accuracy_score,log_loss

X_train,X_test,Y_train,Y_test  = train_test_split(X,Y,test_size = 0.3,random_state=42)
clf.fit(X_train,Y_train)
y_pred_train = clf.predict(X_train)
y_pred_test = clf.predict(X_test)
training_acc.append(accuracy_score(Y_train,y_pred_train))
test_acc.append(accuracy_score(Y_test,y_pred_test))
traning_loss.append(log_loss(Y_train,y_pred_train))
test_loss.append(log_loss(Y_test,y_pred_test))

import numpy as np
print("CV- Traning Accuracy: ",np.mean(training_acc).round(2))
print("CV- Test Accuracy: ",np.mean(test_acc).round(2))
print("CV- Traning loss: ",np.mean(traning_loss).round(2))
print("CV- Test loss: ",np.mean(test_loss).round(2))
print("#===============================================================")
# Evaluate the performance on test data using metrics like accuracy, precision, recall, and F1-score.

from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score

accuracy_poly3 = accuracy_score(Y_test,y_pred_test)
precision_poly3 = precision_score(Y_test, y_pred_test, average='weighted')
recall_poly3 = recall_score(Y_test, y_pred_test, average='weighted')
f1_poly3 = f1_score(Y_test, y_pred_test, average='weighted')

# printing scores

print("Accuracy:", accuracy_poly3)
print("Precision:", precision_poly3)
print("Recall:", recall_poly3)
print("F1 Score:", f1_poly3)
# Out:
# CV- Traning Accuracy:  0.7
# CV- Test Accuracy:  0.69
# CV- Traning loss:  10.68
# CV- Test loss:  11.11
# #===============================================================
# Accuracy: 0.6916666666666667
# Precision: 0.4784027777777778
# Recall: 0.6916666666666667
# F1 Score: 0.56559934318555
# C:\Users\gmani\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %% [markdown]
# # Task 5: Visualization of SVM Results

# %%
# 1.Visualize classification results on the testing data.

# Create a bar chart to compare the performance metrics
import matplotlib.pyplot as plt
metrics = ['Accuracy', 'Precision', 'Recall', 'F1 Score']
rbf_metrics = [accuracy_rbf, precision_rbf, recall_rbf,f1_rbf]
Linear_metrics = [accuracy_Linear, precision_Linear, recall_Linear,f1_Linear]
poly2_metrics = [accuracy_poly2, precision_poly2, recall_poly2,f1_poly2]
poly3_metrics = [accuracy_poly3, precision_poly3, recall_poly3,f1_poly3]

plt.figure(figsize=(10, 6))
plt.bar(metrics, rbf_metrics, label='rbf', alpha=0.8)
plt.bar(metrics, Linear_metrics, label='Linear', alpha=0.8)
plt.bar(metrics, poly2_metrics, label='poly2', alpha=0.8)
plt.bar(metrics, poly3_metrics, label='poly3', alpha=0.8)

plt.xlabel('Metric')
plt.ylabel('Score')
plt.title('Performance Comparison of rbf,Linear,poly2 and poly3 Models')
plt.legend()
plt.show()

# %% [markdown]
# # Task 6: Parameter Tuning and Optimization

# %%
# 1.Experiment with different SVM hyperparameters (e.g., kernel type, regularization parameter) to optimize performance.

# Experiment with different SVM hyperparameters
kernels = ['linear', 'poly', 'rbf']
regularization_parameters = [0.1, 1, 10]

best_accuracy = 0
best_kernel = None
best_regularization_parameter = None

for kernel in kernels:
  for regularization_parameter in regularization_parameters:
    clf = SVC(C=regularization_parameter, kernel=kernel)
    clf.fit(X_train, Y_train)
    y_pred = clf.predict(X_test)
    accuracy = accuracy_score(Y_test, y_pred)
    if accuracy > best_accuracy:
      best_accuracy = accuracy
      best_kernel = kernel
      best_regularization_parameter = regularization_parameter

print("Best accuracy:", best_accuracy)
print("Best kernel:", best_kernel)
print("Best regularization parameter:", best_regularization_parameter)
# Out:
# Best accuracy: 0.6916666666666667
# Best kernel: linear
# Best regularization parameter: 0.1

# %% [markdown]
# # Task 7: Comparison and Analysis

# %%
# 1.Compare SVM performance with various kernels (e.g., linear, polynomial, radial basis function).

# Create a table to compare the performance metrics
metrics = ['Accuracy', 'Precision', 'Recall', 'F1 Score']
rbf_metrics = [accuracy_rbf, precision_rbf, recall_rbf,f1_rbf]
Linear_metrics = [accuracy_Linear, precision_Linear, recall_Linear,f1_Linear]
poly2_metrics = [accuracy_poly2, precision_poly2, recall_poly2,f1_poly2]
poly3_metrics = [accuracy_poly3, precision_poly3, recall_poly3,f1_poly3]

comparison_table = pd.DataFrame({
    'Metric': metrics,
    'linear': Linear_metrics,
    'polynomial-2': poly2_metrics,
    'polynomial-3': poly3_metrics,
    'radial basis function': rbf_metrics
})

comparison_table
# Out:
#       Metric    linear  polynomial-2  polynomial-3  radial basis function
# 0   Accuracy  0.691667      0.691667      0.691667               0.691667
# 1  Precision  0.478403      0.478403      0.478403               0.478403
# 2     Recall  0.691667      0.691667      0.691667               0.691667
# 3   F1 Score  0.565599      0.565599      0.565599               0.565599

# %%
# 2. Analyze SVM strengths and weaknesses for the Mushroom dataset based on EDA and visualization results.

* Strengths:
    - SVM is a powerful classifier that can handle high-dimensional data and complex decision boundaries.
    - It is robust to noise and outliers.
    - It can be used for both binary and multi-class classification.
    
* Weaknesses:
    - SVM can be computationally expensive for large datasets.
    - It can be difficult to choose the optimal hyperparameters.
    - It is not as interpretable as some other classifiers.

# 3. Discuss practical implications of SVM in real-world classification tasks.

SVM is a versatile classifier that can be used for a wide range of real-world classification tasks.

Some examples include:
    - Image classification: SVM can be used to classify images of objects, such as handwritten digits or faces.
    - Text classification: SVM can be used to classify text documents, such as spam or news articles.
    - Medical diagnosis: SVM can be used to diagnose diseases, such as cancer or heart disease.
    - Financial trading: SVM can be used to predict stock prices or currency exchange rates.
